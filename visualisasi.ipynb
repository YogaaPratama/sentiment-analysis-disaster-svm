# %% [markdown]
# haiti vader

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.7840, 0.6995, 0.7876, 0.7670]
precision = [0.8098, 0.7099, 0.7984, 0.8008]
recall = [0.7840, 0.6995, 0.7876, 0.7670]
f1_score = [0.7908, 0.6633, 0.7915, 0.7753]
error_rate = [0.2160, 0.3005, 0.2124, 0.2330]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Haiti Using VADER')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# haiti textblob

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.7389, 0.6298, 0.7258, 0.7286]
precision = [0.7375, 0.6526, 0.7207, 0.7287]
recall = [0.7389, 0.6298, 0.7258, 0.7286]
f1_score = [0.7371, 0.5831, 0.7184, 0.7279]
error_rate = [0.2611, 0.3702, 0.2742, 0.2714]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Haiti Using Textblob')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# eu textblob

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.6241, 0.6080, 0.6357, 0.6381]
precision = [0.6422, 0.5860, 0.6320, 0.6747]
recall = [0.6241, 0.6079, 0.6357, 0.6381]
f1_score = [0.6254, 0.5546, 0.6336, 0.6447]
error_rate = [0.3759, 0.3921, 0.3643, 0.3619]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on EU Using Textblob')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# eu vader

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.6682, 0.6381, 0.6427, 0.6381]
precision = [0.6616, 0.6034, 0.6277, 0.6409]
recall = [0.6682, 0.6381, 0.6427, 0.6381]
f1_score = [0.6640, 0.5735, 0.6331, 0.6381]
error_rate = [0.3318, 0.3619, 0.3573, 0.3619]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on EU Using VADER')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# catania textblob

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.7035, 0.6221, 0.6570, 0.7035]
precision = [0.7258, 0.6343, 0.6543, 0.7255]
recall = [0.7035, 0.6221, 0.6570, 0.7035]
f1_score = [0.7076, 0.6074, 0.6523, 0.7087]
error_rate = [0.2965, 0.3779, 0.3430, 0.2965]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Catania Using Textblob')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# catania vader

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.6512, 0.6047, 0.6221, 0.6047]
precision = [0.7178, 0.5543, 0.6226, 0.6982]
recall = [0.6512, 0.6047, 0.6221, 0.6047]
f1_score = [0.6627, 0.5754, 0.6198, 0.6187]
error_rate = [0.3488, 0.3953, 0.3779, 0.3953]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Catania Using VADER')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# croatia textblob

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.5000, 0.3333, 0.5000, 0.3333]
precision = [0.5056, 0.3185, 0.5056, 0.3519]
recall = [0.5000, 0.3333, 0.5000, 0.3333]
f1_score = [0.5005, 0.3204, 0.5005, 0.3185]
error_rate = [0.5000, 0.6667, 0.5000, 0.6667]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Croatia Using Textblob')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# croatia vader

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the kernels
kernels = ['Linear', 'Poly', 'RBF', 'Sigmoid']
accuracy = [0.5556, 0.6667, 0.6667, 0.3889]
precision = [0.5972, 0.6714, 0.6944, 0.5503]
recall = [0.5556, 0.6667, 0.6667, 0.3889]
f1_score = [0.5651, 0.6655, 0.6683, 0.4094]
error_rate = [0.4444, 0.3333, 0.3333, 0.6111]

# Set the width of the bars
bar_width = 0.15

# Set the positions of the bars on the x-axis
r1 = np.arange(len(kernels))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

# Create the bar chart
plt.figure(figsize=(12, 6))

plt.bar(r1, accuracy, color='blue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, precision, color='green', width=bar_width, edgecolor='grey', label='Precision')
plt.bar(r3, recall, color='red', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r4, f1_score, color='purple', width=bar_width, edgecolor='grey', label='F1 Score')
plt.bar(r5, error_rate, color='orange', width=bar_width, edgecolor='grey', label='Error Rate')

# Add labels to the x-axis
plt.xlabel('Kernels', fontweight='bold')
plt.xticks([r + bar_width*2 for r in range(len(kernels))], kernels)

# Add a title to the chart
plt.title('Kernel Performance Comparison on Croatia Using VADER')

# Add a legend inside a box
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True)

# Show the chart
plt.tight_layout()
plt.show()
