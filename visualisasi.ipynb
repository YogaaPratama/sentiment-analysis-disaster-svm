# %%
#haiti
import matplotlib.pyplot as plt
import numpy as np

# Function to convert time string to seconds
def time_to_seconds(time_str):
    # Parse "0:00:02.508356" format
    minutes, seconds = time_str.split(':')[1:]
    return float(seconds)

# Data kernel dan waktu pelatihan rata-rata
kernels = ["Linear", "Poly", "RBF", "Sigmoid"]
time_strings = [
    "0:00:02.508356",
    "0:00:04.467623", 
    "0:00:03.395077",
    "0:00:02.568167"
]

# Convert time strings to seconds
training_times = [time_to_seconds(t) for t in time_strings]

# Membuat plot diagram batang
plt.figure(figsize=(10, 6))
bars = plt.bar(kernels, training_times, color=['blue', 'green', 'red', 'purple'])

# Menambahkan label dan judul
plt.xlabel("Kernel Type", fontsize=12)
plt.ylabel("Average Training Time (seconds)", fontsize=12)
plt.title("Average Training Time for Different Kernels", fontsize=14, pad=20)

# Set y-axis limit with padding
plt.ylim(0, max(training_times) * 1.1)

# Menampilkan nilai waktu di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.3f}s',
             ha='center', va='bottom')

# Add grid for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.3)

# Adjust layout
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %%
#croatia
import matplotlib.pyplot as plt
import numpy as np

# Function to convert time string to seconds
def time_to_seconds(time_str):
    # Parse "0:00:00.003666" format
    hours, minutes, seconds = time_str.split(':')
    return float(seconds)

# Data kernel dan waktu pelatihan rata-rata
kernels = ["Linear", "Poly", "RBF", "Sigmoid"]
time_strings = [
    "0:00:00.002606",
    "0:00:00.002141", 
    "0:00:00.001427",
    "0:00:00.001662"
]

# Convert time strings to seconds
training_times = [time_to_seconds(t) for t in time_strings]

# Membuat plot diagram batang
plt.figure(figsize=(10, 6))
bars = plt.bar(kernels, training_times, color=['blue', 'green', 'red', 'purple'])

# Menambahkan label dan judul
plt.xlabel("Kernel Type", fontsize=12)
plt.ylabel("Average Training Time (seconds)", fontsize=12)
plt.title("Average Training Time for Different Kernels", fontsize=14, pad=20)

# Set y-axis limit with padding
plt.ylim(0, max(training_times) * 1.1)

# Menampilkan nilai waktu di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.6f}s',
             ha='center', va='bottom')

# Add grid for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.3)

# Adjust layout
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %%
#catania
import matplotlib.pyplot as plt
import numpy as np

# Function to convert time string to seconds
def time_to_seconds(time_str):
    # Parse "0:00:00.003666" format
    hours, minutes, seconds = time_str.split(':')
    return float(seconds)

# Data kernel dan waktu pelatihan rata-rata
kernels = ["Linear", "Poly", "RBF", "Sigmoid"]
time_strings = [
    "0:00:00.003666",
    "0:00:00.003718", 
    "0:00:00.004468",
    "0:00:00.003803"
]

# Convert time strings to seconds
training_times = [time_to_seconds(t) for t in time_strings]

# Membuat plot diagram batang
plt.figure(figsize=(10, 6))
bars = plt.bar(kernels, training_times, color=['blue', 'green', 'red', 'purple'])

# Menambahkan label dan judul
plt.xlabel("Kernel Type", fontsize=12)
plt.ylabel("Average Training Time (seconds)", fontsize=12)
plt.title("Average Training Time for Different Kernels", fontsize=14, pad=20)

# Set y-axis limit with padding
plt.ylim(0, max(training_times) * 1.1)

# Menampilkan nilai waktu di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.6f}s',
             ha='center', va='bottom')

# Add grid for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.3)

# Adjust layout
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %%
#eu
import matplotlib.pyplot as plt
import numpy as np

# Function to convert time string to seconds
def time_to_seconds(time_str):
    # Parse "0:00:00.003666" format
    hours, minutes, seconds = time_str.split(':')
    return float(seconds)

# Data kernel dan waktu pelatihan rata-rata
kernels = ["Linear", "Poly", "RBF", "Sigmoid"]
time_strings = [
    "0:00:00.011200",
    "0:00:00.011468", 
    "0:00:00.013208",
    "0:00:00.023224"
]

# Convert time strings to seconds
training_times = [time_to_seconds(t) for t in time_strings]

# Membuat plot diagram batang
plt.figure(figsize=(10, 6))
bars = plt.bar(kernels, training_times, color=['blue', 'green', 'red', 'purple'])

# Menambahkan label dan judul
plt.xlabel("Kernel Type", fontsize=12)
plt.ylabel("Average Training Time (seconds)", fontsize=12)
plt.title("Average Training Time for Different Kernels", fontsize=14, pad=20)

# Set y-axis limit with padding
plt.ylim(0, max(training_times) * 1.1)

# Menampilkan nilai waktu di atas setiap batang
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.6f}s',
             ha='center', va='bottom')

# Add grid for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.3)

# Adjust layout
plt.tight_layout()

# Menampilkan grafik
plt.show()
